# %%
import numpy as np
import pandas as pd
from PIL import Image
import cv2
import os
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
img = []
mask = []
direc = '/Users/adityavs14/Documents/Internship/Pianalytix/Mask_ground/ML_model/data2/'

# %%
images_dir = []
images_dir = sorted(os.listdir(direc))
print(len(images_dir))

for i in images_dir:
    if 'i2' in i:
        mask.append(i)
    if 't' in i:
        img.append(i)
# Out:
# 15000

# %%
img
# Out:
# ['0001_t.png',
#  '0002_t.png',
#  '0003_t.png',
#  '0004_t.png',
#  '0005_t.png',
#  '0006_t.png',
#  '0007_t.png',
#  '0008_t.png',
#  '0009_t.png',
#  '0010_t.png',
#  '0011_t.png',
#  '0012_t.png',
#  '0013_t.png',
#  '0014_t.png',
#  '0015_t.png',
#  '0016_t.png',
#  '0017_t.png',
#  '0018_t.png',
#  '0019_t.png',
#  '0020_t.png',
#  '0021_t.png',
#  '0022_t.png',
#  '0023_t.png',
#  '0024_t.png',
#  '0025_t.png',
#  '0026_t.png',
#  '0027_t.png',
#  '0028_t.png',
#  '0029_t.png',
#  '0030_t.png',
#  '0031_t.png',
#  '0032_t.png',
#  '0033_t.png',
#  '0034_t.png',
#  '0035_t.png',
#  '0036_t.png',
#  '0037_t.png',
#  '0038_t.png',
#  '0039_t.png',
#  '0040_t.png',
#  '0041_t.png',
#  '0042_t.png',
#  '0043_t.png',
#  '0044_t.png',
#  '0045_t.png',
#  '0046_t.png',
#  '0047_t.png',
#  '0048_t.png',
#  '0049_t.png',
#  '0050_t.png',
#  '0051_t.png',
#  '0052_t.png',
#  '0053_t.png',
#  '0054_t.png',
#  '0055_t.png',
#  '0056_t.png',
#  '0057_t.png',
#  '0058_t.png',
#  '0059_t.png',
#  '0060_t.png',
#  '0061_t.png',
#  '0062_t.png',
#  '0063_t.png',
#  '0064_t.png',
#  '0065_t.png',
#  '0066_t.png',
#  '0067_t.png',
#  '0068_t.png',
#  '0069_t.png',
#  '0070_t.png',
#  '0071_t.png',
#  '0072_t.png',
#  '0073_t.png',
#  '0074_t.png',
#  '0075_t.png',
#  '0076_t.png',
#  '0077_t.png',
#  '0078_t.png',
#  '0079_t.png',
#  '0080_t.png',
#  '0081_t.png',
#  '0082_t.png',
#  '0083_t.png',
#  '0084_t.png',
#  '0085_t.png',
#  '0086_t.png',
#  '0087_t.png',
#  '0088_t.png',
#  '0089_t.png',
#  '0090_t.png',
#  '0091_t.png',
#  '0092_t.png',
#  '0093_t.png',
#  '0094_t.png',
#  '0095_t.png',
#  '0096_t.png',
#  '0097_t.png',
#  '0098_t.png',
#  '0099_t.png',
#  '0100_t.png',
#  '0101_t.png',
#  '0102_t.png',
#  '0103_t.png',
#  '0104_t.png',
#  '0105_t.png',
#  '0106_t.png',
#  '0107_t.png',
#  '0108_t.png',
#  '0109_t.png',
#  '0110_t.png',
#  '0111_t.png',
#  '0112_t.png',
#  '0113_t.png',
#  '0114_t.png',
#  '0115_t.png',
#  '0116_t.png',
#  '0117_t.png',
#  '0118_t.png',
#  '0119_t.png',
#  '0120_t.png',
#  '0121_t.png',
#  '0122_t.png',
#  '0123_t.png',
#  '0124_t.png',
#  '0125_t.png',
#  '0126_t.png',
#  '0127_t.png',
#  '0128_t.png',
#  '0129_t.png',
#  '0130_t.png',
#  '0131_t.png',
#  '0132_t.png',
#  '0133_t.png',
#  '0134_t.png',
#  '0135_t.png',
#  '0136_t.png',
#  '0137_t.png',
#  '0138_t.png',
#  '0139_t.png',
#  '0140_t.png',
#  '0141_t.png',
#  '0142_t.png',
#  '0143_t.png',
#  '0144_t.png',
#  '0145_t.png',
#  '0146_t.png',
#  '0147_t.png',
#  '0148_t.png',
#  '0149_t.png',
#  '0150_t.png',
#  '0151_t.png',
#  '0152_t.png',
#  '0153_t.png',
#  '0154_t.png',
#  '0155_t.png',
#  '0156_t.png',
#  '0157_t.png',
#  '0158_t.png',
#  '0159_t.png',
#  '0160_t.png',
#  '0161_t.png',
#  '0162_t.png',
#  '0163_t.png',
#  '0164_t.png',
#  '0165_t.png',
#  '0166_t.png',
#  '0167_t.png',
#  '0168_t.png',
#  '0169_t.png',
#  '0170_t.png',
#  '0171_t.png',
#  '0172_t.png',
#  '0173_t.png',
#  '0174_t.png',
#  '0175_t.png',
#  '0176_t.png',
#  '0177_t.png',
#  '0178_t.png',
#  '0179_t.png',
#  '0180_t.png',
#  '0181_t.png',
#  '0182_t.png',
#  '0183_t.png',
#  '0184_t.png',
#  '0185_t.png',
#  '0186_t.png',
#  '0187_t.png',
#  '0188_t.png',
#  '0189_t.png',
#  '0190_t.png',
#  '0191_t.png',
#  '0192_t.png',
#  '0193_t.png',
#  '0194_t.png',
#  '0195_t.png',
#  '0196_t.png',
#  '0197_t.png',
#  '0198_t.png',
#  '0199_t.png',
#  '0200_t.png',
#  '0201_t.png',
#  '0202_t.png',
#  '0203_t.png',
#  '0204_t.png',
#  '0205_t.png',
#  '0206_t.png',
#  '0207_t.png',
#  '0208_t.png',
#  '0209_t.png',
#  '0210_t.png',
#  '0211_t.png',
#  '0212_t.png',
#  '0213_t.png',
#  '0214_t.png',
#  '0215_t.png',
#  '0216_t.png',
#  '0217_t.png',
#  '0218_t.png',
#  '0219_t.png',
#  '0220_t.png',
#  '0221_t.png',
#  '0222_t.png',
#  '0223_t.png',
#  '0224_t.png',
#  '0225_t.png',
#  '0226_t.png',
#  '0227_t.png',
#  '0228_t.png',
#  '0229_t.png',
#  '0230_t.png',
#  '0231_t.png',
#  '0232_t.png',
#  '0233_t.png',
#  '0234_t.png',
#  '0235_t.png',
#  '0236_t.png',
#  '0237_t.png',
#  '0238_t.png',
#  '0239_t.png',
#  '0240_t.png',
#  '0241_t.png',
#  '0242_t.png',
#  '0243_t.png',
#  '0244_t.png',
#  '0245_t.png',
#  '0246_t.png',
#  '0247_t.png',
#  '0248_t.png',
#  '0249_t.png',
#  '0250_t.png',
#  '0251_t.png',
#  '0252_t.png',
#  '0253_t.png',
#  '0254_t.png',
#  '0255_t.png',
#  '0256_t.png',
#  '0257_t.png',
#  '0258_t.png',
#  '0259_t.png',
#  '0260_t.png',
#  '0261_t.png',
#  '0262_t.png',
#  '0263_t.png',
#  '0264_t.png',
#  '0265_t.png',
#  '0266_t.png',
#  '0267_t.png',
#  '0268_t.png',
#  '0269_t.png',
#  '0270_t.png',
#  '0271_t.png',
#  '0272_t.png',
#  '0273_t.png',
#  '0274_t.png',
#  '0275_t.png',
#  '0276_t.png',
#  '0277_t.png',
#  '0278_t.png',
#  '0279_t.png',
#  '0280_t.png',
#  '0281_t.png',
#  '0282_t.png',
#  '0283_t.png',
#  '0284_t.png',
#  '0285_t.png',
#  '0286_t.png',
#  '0287_t.png',
#  '0288_t.png',
#  '0289_t.png',
#  '0290_t.png',
#  '0291_t.png',
#  '0292_t.png',
#  '0293_t.png',
#  '0294_t.png',
#  '0295_t.png',
#  '0296_t.png',
#  '0297_t.png',
#  '0298_t.png',
#  '0299_t.png',
#  '0300_t.png',
#  '0301_t.png',
#  '0302_t.png',
#  '0303_t.png',
#  '0304_t.png',
#  '0305_t.png',
#  '0306_t.png',
#  '0307_t.png',
#  '0308_t.png',
#  '0309_t.png',
#  '0310_t.png',
#  '0311_t.png',
#  '0312_t.png',
#  '0313_t.png',
#  '0314_t.png',
#  '0315_t.png',
#  '0316_t.png',
#  '0317_t.png',
#  '0318_t.png',
#  '0319_t.png',
#  '0320_t.png',
#  '0321_t.png',
#  '0322_t.png',
#  '0323_t.png',
#  '0324_t.png',
#  '0325_t.png',
#  '0326_t.png',
#  '0327_t.png',
#  '0328_t.png',
#  '0329_t.png',
#  '0330_t.png',
#  '0331_t.png',
#  '0332_t.png',
#  '0333_t.png',
#  '0334_t.png',
#  '0335_t.png',
#  '0336_t.png',
#  '0337_t.png',
#  '0338_t.png',
#  '0339_t.png',
#  '0340_t.png',
#  '0341_t.png',
#  '0342_t.png',
#  '0343_t.png',
#  '0344_t.png',
#  '0345_t.png',
#  '0346_t.png',
#  '0347_t.png',
#  '0348_t.png',
#  '0349_t.png',
#  '0350_t.png',
#  '0351_t.png',
#  '0352_t.png',
#  '0353_t.png',
#  '0354_t.png',
#  '0355_t.png',
#  '0356_t.png',
#  '0357_t.png',
#  '0358_t.png',
#  '0359_t.png',
#  '0360_t.png',
#  '0361_t.png',
#  '0362_t.png',
#  '0363_t.png',
#  '0364_t.png',
#  '0365_t.png',
#  '0366_t.png',
#  '0367_t.png',
#  '0368_t.png',
#  '0369_t.png',
#  '0370_t.png',
#  '0371_t.png',
#  '0372_t.png',
#  '0373_t.png',
#  '0374_t.png',
#  '0375_t.png',
#  '0376_t.png',
#  '0377_t.png',
#  '0378_t.png',
#  '0379_t.png',
#  '0380_t.png',
#  '0381_t.png',
#  '0382_t.png',
#  '0383_t.png',
#  '0384_t.png',
#  '0385_t.png',
#  '0386_t.png',
#  '0387_t.png',
#  '0388_t.png',
#  '0389_t.png',
#  '0390_t.png',
#  '0391_t.png',
#  '0392_t.png',
#  '0393_t.png',
#  '0394_t.png',
#  '0395_t.png',
#  '0396_t.png',
#  '0397_t.png',
#  '0398_t.png',
#  '0399_t.png',
#  '0400_t.png',
#  '0401_t.png',
#  '0402_t.png',
#  '0403_t.png',
#  '0404_t.png',
#  '0405_t.png',
#  '0406_t.png',
#  '0407_t.png',
#  '0408_t.png',
#  '0409_t.png',
#  '0410_t.png',
#  '0411_t.png',
#  '0412_t.png',
#  '0413_t.png',
#  '0414_t.png',
#  '0415_t.png',
#  '0416_t.png',
#  '0417_t.png',
#  '0418_t.png',
#  '0419_t.png',
#  '0420_t.png',
#  '0421_t.png',
#  '0422_t.png',
#  '0423_t.png',
#  '0424_t.png',
#  '0425_t.png',
#  '0426_t.png',
#  '0427_t.png',
#  '0428_t.png',
#  '0429_t.png',
#  '0430_t.png',
#  '0431_t.png',
#  '0432_t.png',
#  '0433_t.png',
#  '0434_t.png',
#  '0435_t.png',
#  '0436_t.png',
#  '0437_t.png',
#  '0438_t.png',
#  '0439_t.png',
#  '0440_t.png',
#  '0441_t.png',
#  '0442_t.png',
#  '0443_t.png',
#  '0444_t.png',
#  '0445_t.png',
#  '0446_t.png',
#  '0447_t.png',
#  '0448_t.png',
#  '0449_t.png',
#  '0450_t.png',
#  '0451_t.png',
#  '0452_t.png',
#  '0453_t.png',
#  '0454_t.png',
#  '0455_t.png',
#  '0456_t.png',
#  '0457_t.png',
#  '0458_t.png',
#  '0459_t.png',
#  '0460_t.png',
#  '0461_t.png',
#  '0462_t.png',
#  '0463_t.png',
#  '0464_t.png',
#  '0465_t.png',
#  '0466_t.png',
#  '0467_t.png',
#  '0468_t.png',
#  '0469_t.png',
#  '0470_t.png',
#  '0471_t.png',
#  '0472_t.png',
#  '0473_t.png',
#  '0474_t.png',
#  '0475_t.png',
#  '0476_t.png',
#  '0477_t.png',
#  '0478_t.png',
#  '0479_t.png',
#  '0480_t.png',
#  '0481_t.png',
#  '0482_t.png',
#  '0483_t.png',
#  '0484_t.png',
#  '0485_t.png',
#  '0486_t.png',
#  '0487_t.png',
#  '0488_t.png',
#  '0489_t.png',
#  '0490_t.png',
#  '0491_t.png',
#  '0492_t.png',
#  '0493_t.png',
#  '0494_t.png',
#  '0495_t.png',
#  '0496_t.png',
#  '0497_t.png',
#  '0498_t.png',
#  '0499_t.png',
#  '0500_t.png',
#  '0501_t.png',
#  '0502_t.png',
#  '0503_t.png',
#  '0504_t.png',
#  '0505_t.png',
#  '0506_t.png',
#  '0507_t.png',
#  '0508_t.png',
#  '0509_t.png',
#  '0510_t.png',
#  '0511_t.png',
#  '0512_t.png',
#  '0513_t.png',
#  '0514_t.png',
#  '0515_t.png',
#  '0516_t.png',
#  '0517_t.png',
#  '0518_t.png',
#  '0519_t.png',
#  '0520_t.png',
#  '0521_t.png',
#  '0522_t.png',
#  '0523_t.png',
#  '0524_t.png',
#  '0525_t.png',
#  '0526_t.png',
#  '0527_t.png',
#  '0528_t.png',
#  '0529_t.png',
#  '0530_t.png',
#  '0531_t.png',
#  '0532_t.png',
#  '0533_t.png',
#  '0534_t.png',
#  '0535_t.png',
#  '0536_t.png',
#  '0537_t.png',
#  '0538_t.png',
#  '0539_t.png',
#  '0540_t.png',
#  '0541_t.png',
#  '0542_t.png',
#  '0543_t.png',
#  '0544_t.png',
#  '0545_t.png',
#  '0546_t.png',
#  '0547_t.png',
#  '0548_t.png',
#  '0549_t.png',
#  '0550_t.png',
#  '0551_t.png',
#  '0552_t.png',
#  '0553_t.png',
#  '0554_t.png',
#  '0555_t.png',
#  '0556_t.png',
#  '0557_t.png',
#  '0558_t.png',
#  '0559_t.png',
#  '0560_t.png',
#  '0561_t.png',
#  '0562_t.png',
#  '0563_t.png',
#  '0564_t.png',
#  '0565_t.png',
#  '0566_t.png',
#  '0567_t.png',
#  '0568_t.png',
#  '0569_t.png',
#  '0570_t.png',
#  '0571_t.png',
#  '0572_t.png',
#  '0573_t.png',
#  '0574_t.png',
#  '0575_t.png',
#  '0576_t.png',
#  '0577_t.png',
#  '0578_t.png',
#  '0579_t.png',
#  '0580_t.png',
#  '0581_t.png',
#  '0582_t.png',
#  '0583_t.png',
#  '0584_t.png',
#  '0585_t.png',
#  '0586_t.png',
#  '0587_t.png',
#  '0588_t.png',
#  '0589_t.png',
#  '0590_t.png',
#  '0591_t.png',
#  '0592_t.png',
#  '0593_t.png',
#  '0594_t.png',
#  '0595_t.png',
#  '0596_t.png',
#  '0597_t.png',
#  '0598_t.png',
#  '0599_t.png',
#  '0600_t.png',
#  '0601_t.png',
#  '0602_t.png',
#  '0603_t.png',
#  '0604_t.png',
#  '0605_t.png',
#  '0606_t.png',
#  '0607_t.png',
#  '0608_t.png',
#  '0609_t.png',
#  '0610_t.png',
#  '0611_t.png',
#  '0612_t.png',
#  '0613_t.png',
#  '0614_t.png',
#  '0615_t.png',
#  '0616_t.png',
#  '0617_t.png',
#  '0618_t.png',
#  '0619_t.png',
#  '0620_t.png',
#  '0621_t.png',
#  '0622_t.png',
#  '0623_t.png',
#  '0624_t.png',
#  '0625_t.png',
#  '0626_t.png',
#  '0627_t.png',
#  '0628_t.png',
#  '0629_t.png',
#  '0630_t.png',
#  '0631_t.png',
#  '0632_t.png',
#  '0633_t.png',
#  '0634_t.png',
#  '0635_t.png',
#  '0636_t.png',
#  '0637_t.png',
#  '0638_t.png',
#  '0639_t.png',
#  '0640_t.png',
#  '0641_t.png',
#  '0642_t.png',
#  '0643_t.png',
#  '0644_t.png',
#  '0645_t.png',
#  '0646_t.png',
#  '0647_t.png',
#  '0648_t.png',
#  '0649_t.png',
#  '0650_t.png',
#  '0651_t.png',
#  '0652_t.png',
#  '0653_t.png',
#  '0654_t.png',
#  '0655_t.png',
#  '0656_t.png',
#  '0657_t.png',
#  '0658_t.png',
#  '0659_t.png',
#  '0660_t.png',
#  '0661_t.png',
#  '0662_t.png',
#  '0663_t.png',
#  '0664_t.png',
#  '0665_t.png',
#  '0666_t.png',
#  '0667_t.png',
#  '0668_t.png',
#  '0669_t.png',
#  '0670_t.png',
#  '0671_t.png',
#  '0672_t.png',
#  '0673_t.png',
#  '0674_t.png',
#  '0675_t.png',
#  '0676_t.png',
#  '0677_t.png',
#  '0678_t.png',
#  '0679_t.png',
#  '0680_t.png',
#  '0681_t.png',
#  '0682_t.png',
#  '0683_t.png',
#  '0684_t.png',
#  '0685_t.png',
#  '0686_t.png',
#  '0687_t.png',
#  '0688_t.png',
#  '0689_t.png',
#  '0690_t.png',
#  '0691_t.png',
#  '0692_t.png',
#  '0693_t.png',
#  '0694_t.png',
#  '0695_t.png',
#  '0696_t.png',
#  '0697_t.png',
#  '0698_t.png',
#  '0699_t.png',
#  '0700_t.png',
#  '0701_t.png',
#  '0702_t.png',
#  '0703_t.png',
#  '0704_t.png',
#  '0705_t.png',
#  '0706_t.png',
#  '0707_t.png',
#  '0708_t.png',
#  '0709_t.png',
#  '0710_t.png',
#  '0711_t.png',
#  '0712_t.png',
#  '0713_t.png',
#  '0714_t.png',
#  '0715_t.png',
#  '0716_t.png',
#  '0717_t.png',
#  '0718_t.png',
#  '0719_t.png',
#  '0720_t.png',
#  '0721_t.png',
#  '0722_t.png',
#  '0723_t.png',
#  '0724_t.png',
#  '0725_t.png',
#  '0726_t.png',
#  '0727_t.png',
#  '0728_t.png',
#  '0729_t.png',
#  '0730_t.png',
#  '0731_t.png',
#  '0732_t.png',
#  '0733_t.png',
#  '0734_t.png',
#  '0735_t.png',
#  '0736_t.png',
#  '0737_t.png',
#  '0738_t.png',
#  '0739_t.png',
#  '0740_t.png',
#  '0741_t.png',
#  '0742_t.png',
#  '0743_t.png',
#  '0744_t.png',
#  '0745_t.png',
#  '0746_t.png',
#  '0747_t.png',
#  '0748_t.png',
#  '0749_t.png',
#  '0750_t.png',
#  '0751_t.png',
#  '0752_t.png',
#  '0753_t.png',
#  '0754_t.png',
#  '0755_t.png',
#  '0756_t.png',
#  '0757_t.png',
#  '0758_t.png',
#  '0759_t.png',
#  '0760_t.png',
#  '0761_t.png',
#  '0762_t.png',
#  '0763_t.png',
#  '0764_t.png',
#  '0765_t.png',
#  '0766_t.png',
#  '0767_t.png',
#  '0768_t.png',
#  '0769_t.png',
#  '0770_t.png',
#  '0771_t.png',
#  '0772_t.png',
#  '0773_t.png',
#  '0774_t.png',
#  '0775_t.png',
#  '0776_t.png',
#  '0777_t.png',
#  '0778_t.png',
#  '0779_t.png',
#  '0780_t.png',
#  '0781_t.png',
#  '0782_t.png',
#  '0783_t.png',
#  '0784_t.png',
#  '0785_t.png',
#  '0786_t.png',
#  '0787_t.png',
#  '0788_t.png',
#  '0789_t.png',
#  '0790_t.png',
#  '0791_t.png',
#  '0792_t.png',
#  '0793_t.png',
#  '0794_t.png',
#  '0795_t.png',
#  '0796_t.png',
#  '0797_t.png',
#  '0798_t.png',
#  '0799_t.png',
#  '0800_t.png',
#  '0801_t.png',
#  '0802_t.png',
#  '0803_t.png',
#  '0804_t.png',
#  '0805_t.png',
#  '0806_t.png',
#  '0807_t.png',
#  '0808_t.png',
#  '0809_t.png',
#  '0810_t.png',
#  '0811_t.png',
#  '0812_t.png',
#  '0813_t.png',
#  '0814_t.png',
#  '0815_t.png',
#  '0816_t.png',
#  '0817_t.png',
#  '0818_t.png',
#  '0819_t.png',
#  '0820_t.png',
#  '0821_t.png',
#  '0822_t.png',
#  '0823_t.png',
#  '0824_t.png',
#  '0825_t.png',
#  '0826_t.png',
#  '0827_t.png',
#  '0828_t.png',
#  '0829_t.png',
#  '0830_t.png',
#  '0831_t.png',
#  '0832_t.png',
#  '0833_t.png',
#  '0834_t.png',
#  '0835_t.png',
#  '0836_t.png',
#  '0837_t.png',
#  '0838_t.png',
#  '0839_t.png',
#  '0840_t.png',
#  '0841_t.png',
#  '0842_t.png',
#  '0843_t.png',
#  '0844_t.png',
#  '0845_t.png',
#  '0846_t.png',
#  '0847_t.png',
#  '0848_t.png',
#  '0849_t.png',
#  '0850_t.png',
#  '0851_t.png',
#  '0852_t.png',
#  '0853_t.png',
#  '0854_t.png',
#  '0855_t.png',
#  '0856_t.png',
#  '0857_t.png',
#  '0858_t.png',
#  '0859_t.png',
#  '0860_t.png',
#  '0861_t.png',
#  '0862_t.png',
#  '0863_t.png',
#  '0864_t.png',
#  '0865_t.png',
#  '0866_t.png',
#  '0867_t.png',
#  '0868_t.png',
#  '0869_t.png',
#  '0870_t.png',
#  '0871_t.png',
#  '0872_t.png',
#  '0873_t.png',
#  '0874_t.png',
#  '0875_t.png',
#  '0876_t.png',
#  '0877_t.png',
#  '0878_t.png',
#  '0879_t.png',
#  '0880_t.png',
#  '0881_t.png',
#  '0882_t.png',
#  '0883_t.png',
#  '0884_t.png',
#  '0885_t.png',
#  '0886_t.png',
#  '0887_t.png',
#  '0888_t.png',
#  '0889_t.png',
#  '0890_t.png',
#  '0891_t.png',
#  '0892_t.png',
#  '0893_t.png',
#  '0894_t.png',
#  '0895_t.png',
#  '0896_t.png',
#  '0897_t.png',
#  '0898_t.png',
#  '0899_t.png',
#  '0900_t.png',
#  '0901_t.png',
#  '0902_t.png',
#  '0903_t.png',
#  '0904_t.png',
#  '0905_t.png',
#  '0906_t.png',
#  '0907_t.png',
#  '0908_t.png',
#  '0909_t.png',
#  '0910_t.png',
#  '0911_t.png',
#  '0912_t.png',
#  '0913_t.png',
#  '0914_t.png',
#  '0915_t.png',
#  '0916_t.png',
#  '0917_t.png',
#  '0918_t.png',
#  '0919_t.png',
#  '0920_t.png',
#  '0921_t.png',
#  '0922_t.png',
#  '0923_t.png',
#  '0924_t.png',
#  '0925_t.png',
#  '0926_t.png',
#  '0927_t.png',
#  '0928_t.png',
#  '0929_t.png',
#  '0930_t.png',
#  '0931_t.png',
#  '0932_t.png',
#  '0933_t.png',
#  '0934_t.png',
#  '0935_t.png',
#  '0936_t.png',
#  '0937_t.png',
#  '0938_t.png',
#  '0939_t.png',
#  '0940_t.png',
#  '0941_t.png',
#  '0942_t.png',
#  '0943_t.png',
#  '0944_t.png',
#  '0945_t.png',
#  '0946_t.png',
#  '0947_t.png',
#  '0948_t.png',
#  '0949_t.png',
#  '0950_t.png',
#  '0951_t.png',
#  '0952_t.png',
#  '0953_t.png',
#  '0954_t.png',
#  '0955_t.png',
#  '0956_t.png',
#  '0957_t.png',
#  '0958_t.png',
#  '0959_t.png',
#  '0960_t.png',
#  '0961_t.png',
#  '0962_t.png',
#  '0963_t.png',
#  '0964_t.png',
#  '0965_t.png',
#  '0966_t.png',
#  '0967_t.png',
#  '0968_t.png',
#  '0969_t.png',
#  '0970_t.png',
#  '0971_t.png',
#  '0972_t.png',
#  '0973_t.png',
#  '0974_t.png',
#  '0975_t.png',
#  '0976_t.png',
#  '0977_t.png',
#  '0978_t.png',
#  '0979_t.png',
#  '0980_t.png',
#  '0981_t.png',
#  '0982_t.png',
#  '0983_t.png',
#  '0984_t.png',
#  '0985_t.png',
#  '0986_t.png',
#  '0987_t.png',
#  '0988_t.png',
#  '0989_t.png',
#  '0990_t.png',
#  '0991_t.png',
#  '0992_t.png',
#  '0993_t.png',
#  '0994_t.png',
#  '0995_t.png',
#  '0996_t.png',
#  '0997_t.png',
#  '0998_t.png',
#  '0999_t.png',
#  '1000_t.png',
#  ...]

# %%
md = pd.DataFrame({'Images':img,'Mask':mask},index=range(5000))

# %%
md.head()
# Out:
#        Images         Mask
# 0  0001_t.png  0001_i2.png
# 1  0002_t.png  0002_i2.png
# 2  0003_t.png  0003_i2.png
# 3  0004_t.png  0004_i2.png
# 4  0005_t.png  0005_i2.png

# %%
md.loc[0]
# Out:
# Images     0001_t.png
# Mask      0001_i2.png
# Name: 0, dtype: object

# %%
img = []
mask = []
shape = (128,128)

    
df ={'Image' : [],'Mask' : []}

for i in tqdm(range(len(md))):
    i_dir = direc + md.loc[i][0]
    m_dir = direc + md.loc[i][1]
    t_i = plt.imread(i_dir)
    t_m = plt.imread(m_dir)
    df['Image'].append(cv2.resize(t_i, shape))
    df['Mask'].append(cv2.resize(t_m, shape))
# Out:
# 100%|██████████████████████████████████████| 5000/5000 [00:47<00:00, 105.41it/s]

# %%
plt.figure(figsize = (7, 7))
plt.subplot(1,2,1)
plt.imshow(df['Image'][10])
plt.subplot(1,2,2)
plt.imshow(df['Mask'][10])
plt.show()

# %% [markdown]
# # Unet

# %%
from keras.layers import Conv2D, Conv2DTranspose, MaxPooling2D, BatchNormalization, Dropout, Dense, Activation, concatenate
import tensorflow as tf

#Block

def block(inputImage, numFilters = 16, droupouts = 0.1, doBatchNorm = True, k = 3):
    c1 = tf.keras.layers.Conv2D(numFilters*1,kernel_size=(k,k),kernel_initializer = 'he_normal', padding = 'same')(inputImage)
    c1 = tf.keras.layers.BatchNormalization()(c1)
    c1 = tf.keras.layers.Activation('relu')(c1)
    c1 = tf.keras.layers.Conv2D(numFilters*1,kernel_size=(k,k),kernel_initializer = 'he_normal', padding = 'same')(c1)
    c1 = tf.keras.layers.BatchNormalization()(c1)
    c1 = tf.keras.layers.Activation('relu')(c1)
    
    p1 = tf.keras.layers.MaxPooling2D((2,2))(c1)
    p1 = tf.keras.layers.Dropout(0.1)(p1)
    
    c2 = tf.keras.layers.Conv2D(numFilters*2, kernel_size=(k,k),kernel_initializer = 'he_normal', padding = 'same')(p1)
    c2 = tf.keras.layers.BatchNormalization()(c2)
    c2 = tf.keras.layers.Activation('relu')(c2)
    c2 = tf.keras.layers.Conv2D(numFilters*2, kernel_size=(k,k),kernel_initializer = 'he_normal', padding = 'same')(c2)
    c2 = tf.keras.layers.BatchNormalization()(c2)
    c2 = tf.keras.layers.Activation('relu')(c2)
    
    p2 = tf.keras.layers.MaxPooling2D((2,2))(c2)
    p2 = tf.keras.layers.Dropout(0.1)(p2)
    
    c3 = tf.keras.layers.Conv2D(numFilters*4, kernel_size=(k,k),kernel_initializer = 'he_normal', padding = 'same')(p2)
    c3 = tf.keras.layers.BatchNormalization()(c3)
    c3 = tf.keras.layers.Activation('relu')(c3)
    c3 = tf.keras.layers.Conv2D(numFilters*4, kernel_size=(k,k),kernel_initializer = 'he_normal', padding = 'same')(c3)
    c3 = tf.keras.layers.BatchNormalization()(c3)
    c3 = tf.keras.layers.Activation('relu')(c3)
    
    p3 = tf.keras.layers.MaxPooling2D((2,2))(c3)
    p3 = tf.keras.layers.Dropout(0.1)(p3)
    
    c4 = tf.keras.layers.Conv2D(numFilters*8, kernel_size=(k,k),kernel_initializer = 'he_normal', padding = 'same')(p3)
    c4 = tf.keras.layers.BatchNormalization()(c4)
    c4 = tf.keras.layers.Activation('relu')(c4)
    c4 = tf.keras.layers.Conv2D(numFilters*8, kernel_size=(k,k),kernel_initializer = 'he_normal', padding = 'same')(c4)
    c4 = tf.keras.layers.BatchNormalization()(c4)
    c4 = tf.keras.layers.Activation('relu')(c4)
    
    p4 = tf.keras.layers.MaxPooling2D((2,2))(c4)
    p4 = tf.keras.layers.Dropout(0.1)(p4)
    
    c5 = tf.keras.layers.Conv2D(numFilters*16, kernel_size=(k,k),kernel_initializer = 'he_normal', padding = 'same')(p4)
    c5 = tf.keras.layers.BatchNormalization()(c5)
    c5 = tf.keras.layers.Activation('relu')(c5)
    c5 = tf.keras.layers.Conv2D(numFilters*16,kernel_size=(k,k),kernel_initializer = 'he_normal', padding = 'same')(c5)
    c5 = tf.keras.layers.BatchNormalization()(c5)
    c5 = tf.keras.layers.Activation('relu')(c5)
    
    
    u6 = tf.keras.layers.Conv2DTranspose(numFilters*8, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = tf.keras.layers.concatenate([u6, c4])
    u6 = tf.keras.layers.Dropout(droupouts)(u6)
    
    c6 = tf.keras.layers.Conv2D(numFilters*8, kernel_size=(k,k),kernel_initializer = 'he_normal', padding = 'same')(u6)
    c6 = tf.keras.layers.BatchNormalization()(c6)
    c6 = tf.keras.layers.Activation('relu')(c6)
    c6 = tf.keras.layers.Conv2D(numFilters*8, kernel_size=(k,k),kernel_initializer = 'he_normal', padding = 'same')(c6)
    c6 = tf.keras.layers.BatchNormalization()(c6)
    c6 = tf.keras.layers.Activation('relu')(c6)
    
    
    u7 = tf.keras.layers.Conv2DTranspose(numFilters*4, (3, 3), strides = (2, 2), padding = 'same')(c6)
    u7 = tf.keras.layers.concatenate([u7, c3])
    u7 = tf.keras.layers.Dropout(droupouts)(u7)
    
    c7 = tf.keras.layers.Conv2D(numFilters*4, kernel_size=(k,k),kernel_initializer = 'he_normal', padding = 'same')(u7)
    c7 = tf.keras.layers.BatchNormalization()(c7)
    c7 = tf.keras.layers.Activation('relu')(c7)
    c7 = tf.keras.layers.Conv2D(numFilters*4, kernel_size=(k,k),kernel_initializer = 'he_normal', padding = 'same')(c7)
    c7 = tf.keras.layers.BatchNormalization()(c7)
    c7 = tf.keras.layers.Activation('relu')(c7)
    
    u8 = tf.keras.layers.Conv2DTranspose(numFilters*2, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = tf.keras.layers.concatenate([u8, c2])
    u8 = tf.keras.layers.Dropout(droupouts)(u8)
    
    c8 = tf.keras.layers.Conv2D(numFilters*2, kernel_size=(k,k),kernel_initializer = 'he_normal', padding = 'same')(u8)
    c8 = tf.keras.layers.BatchNormalization()(c8)
    c8 = tf.keras.layers.Activation('relu')(c8)
    c8 = tf.keras.layers.Conv2D(numFilters*2, kernel_size=(k,k),kernel_initializer = 'he_normal', padding = 'same')(c8)
    c8 = tf.keras.layers.BatchNormalization()(c8)
    c8 = tf.keras.layers.Activation('relu')(c8)
    
    
    u9 = tf.keras.layers.Conv2DTranspose(numFilters*1, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = tf.keras.layers.concatenate([u9, c1])
    u9 = tf.keras.layers.Dropout(droupouts)(u9)
    
    c9 = tf.keras.layers.Conv2D(numFilters*2, kernel_size=(k,k),kernel_initializer = 'he_normal', padding = 'same')(u9)
    c9 = tf.keras.layers.BatchNormalization()(c9)
    c9 = tf.keras.layers.Activation('relu')(c9)
    c9 = tf.keras.layers.Conv2D(numFilters*2,kernel_size=(k,k),kernel_initializer = 'he_normal', padding = 'same')(c9)
    c9 = tf.keras.layers.BatchNormalization()(c9)
    c9 = tf.keras.layers.Activation('relu')(c9)
    
    
    
    output = tf.keras.layers.Conv2D(3, (1, 1), activation = 'sigmoid')(c9)
    model = tf.keras.Model(inputs = [inputImage], outputs = [output])
    
    
    return model

# %%
inputs = tf.keras.layers.Input((128, 128, 3))

myTransformer = block(inputs, droupouts= 0.07)
myTransformer.compile(optimizer = 'Adam', loss = 'binary_crossentropy', metrics = ['accuracy'] )

# %%
retVal = myTransformer.fit(np.array(df['Image']), np.array(df['Mask']), epochs = 50, verbose = 1)
# Out:
# Epoch 1/50
# 157/157 [==============================] - 56s 355ms/step - loss: 0.5824 - accuracy: 0.7466
# Epoch 2/50
# 157/157 [==============================] - 55s 352ms/step - loss: 0.5646 - accuracy: 0.7946
# Epoch 3/50
# 157/157 [==============================] - 55s 353ms/step - loss: 0.5619 - accuracy: 0.8043
# Epoch 4/50
# 157/157 [==============================] - 55s 348ms/step - loss: 0.5607 - accuracy: 0.8163
# Epoch 5/50
# 157/157 [==============================] - 56s 355ms/step - loss: 0.5601 - accuracy: 0.8188
# Epoch 6/50
# 157/157 [==============================] - 54s 347ms/step - loss: 0.5592 - accuracy: 0.8296
# Epoch 7/50
# 157/157 [==============================] - 55s 350ms/step - loss: 0.5582 - accuracy: 0.8425
# Epoch 8/50
# 157/157 [==============================] - 54s 343ms/step - loss: 0.5577 - accuracy: 0.8509
# Epoch 9/50
# 157/157 [==============================] - 54s 345ms/step - loss: 0.5576 - accuracy: 0.8511
# Epoch 10/50
# 157/157 [==============================] - 54s 343ms/step - loss: 0.5568 - accuracy: 0.8546
# Epoch 11/50
# 157/157 [==============================] - 55s 352ms/step - loss: 0.5565 - accuracy: 0.8658
# Epoch 12/50
# 157/157 [==============================] - 54s 346ms/step - loss: 0.5558 - accuracy: 0.8595
# Epoch 13/50
# 157/157 [==============================] - 55s 353ms/step - loss: 0.5555 - accuracy: 0.8715
# Epoch 14/50
# 157/157 [==============================] - 54s 345ms/step - loss: 0.5552 - accuracy: 0.8690
# Epoch 15/50
# 157/157 [==============================] - 55s 348ms/step - loss: 0.5548 - accuracy: 0.8752
# Epoch 16/50
# 157/157 [==============================] - 54s 346ms/step - loss: 0.5549 - accuracy: 0.8772
# Epoch 17/50
# 157/157 [==============================] - 56s 356ms/step - loss: 0.5547 - accuracy: 0.8798
# Epoch 18/50
# 157/157 [==============================] - 54s 347ms/step - loss: 0.5544 - accuracy: 0.8775
# Epoch 19/50
# 157/157 [==============================] - 54s 345ms/step - loss: 0.5537 - accuracy: 0.8894
# Epoch 20/50
# 157/157 [==============================] - 55s 350ms/step - loss: 0.5538 - accuracy: 0.8856
# Epoch 21/50
# 157/157 [==============================] - 57s 361ms/step - loss: 0.5536 - accuracy: 0.8863
# Epoch 22/50
# 157/157 [==============================] - 56s 355ms/step - loss: 0.5538 - accuracy: 0.8853
# Epoch 23/50
# 157/157 [==============================] - 55s 353ms/step - loss: 0.5531 - accuracy: 0.8925
# Epoch 24/50
# 157/157 [==============================] - 57s 361ms/step - loss: 0.5529 - accuracy: 0.8969
# Epoch 25/50
# 157/157 [==============================] - 56s 358ms/step - loss: 0.5532 - accuracy: 0.8913
# Epoch 26/50
# 157/157 [==============================] - 56s 357ms/step - loss: 0.5529 - accuracy: 0.8969
# Epoch 27/50
# 157/157 [==============================] - 56s 356ms/step - loss: 0.5527 - accuracy: 0.8948
# Epoch 28/50
# 157/157 [==============================] - 56s 356ms/step - loss: 0.5530 - accuracy: 0.8947
# Epoch 29/50
# 157/157 [==============================] - 56s 354ms/step - loss: 0.5525 - accuracy: 0.8952
# Epoch 30/50
# 157/157 [==============================] - 56s 355ms/step - loss: 0.5523 - accuracy: 0.9000
# Epoch 31/50
# 157/157 [==============================] - 56s 357ms/step - loss: 0.5523 - accuracy: 0.9016
# Epoch 32/50
# 157/157 [==============================] - 55s 351ms/step - loss: 0.5520 - accuracy: 0.9001
# Epoch 33/50
# 157/157 [==============================] - 56s 356ms/step - loss: 0.5520 - accuracy: 0.9065
# Epoch 34/50
# 157/157 [==============================] - 57s 362ms/step - loss: 0.5520 - accuracy: 0.9017
# Epoch 35/50
# 157/157 [==============================] - 58s 372ms/step - loss: 0.5517 - accuracy: 0.9033
# Epoch 36/50
# 157/157 [==============================] - 56s 357ms/step - loss: 0.5516 - accuracy: 0.9037
# Epoch 37/50
# 157/157 [==============================] - 55s 350ms/step - loss: 0.5520 - accuracy: 0.9031
# Epoch 38/50
# 157/157 [==============================] - 55s 350ms/step - loss: 0.5515 - accuracy: 0.9067
# Epoch 39/50
# 157/157 [==============================] - 54s 345ms/step - loss: 0.5515 - accuracy: 0.9014
# Epoch 40/50
# 157/157 [==============================] - 54s 343ms/step - loss: 0.5517 - accuracy: 0.9045
# Epoch 41/50
# 157/157 [==============================] - 54s 342ms/step - loss: 0.5518 - accuracy: 0.9044
# Epoch 42/50
# 157/157 [==============================] - 54s 344ms/step - loss: 0.5512 - accuracy: 0.9074
# Epoch 43/50
# 157/157 [==============================] - 55s 347ms/step - loss: 0.5511 - accuracy: 0.9111
# Epoch 44/50
# 157/157 [==============================] - 55s 348ms/step - loss: 0.5518 - accuracy: 0.9065
# Epoch 45/50
# 157/157 [==============================] - 54s 346ms/step - loss: 0.5513 - accuracy: 0.9110
# Epoch 46/50
# 157/157 [==============================] - 55s 349ms/step - loss: 0.5510 - accuracy: 0.9152
# Epoch 47/50
# 157/157 [==============================] - 55s 350ms/step - loss: 0.5510 - accuracy: 0.9162
# Epoch 48/50
# 157/157 [==============================] - 54s 344ms/step - loss: 0.5514 - accuracy: 0.9147
# Epoch 49/50
# 157/157 [==============================] - 55s 349ms/step - loss: 0.5509 - accuracy: 0.9189
# Epoch 50/50
# 157/157 [==============================] - 55s 349ms/step - loss: 0.5508 - accuracy: 0.9205

# %%
myTransformer.save('TerrainMaskGenerator.h5')

# %%
## function for getting 16 predictions
def predict16 (valMap, model, shape = 256):
    ## getting and proccessing val data
    img = valMap['Image']
    mask = valMap['Mask']
    mask = mask[0:16]
    
    imgProc = img [0:16]
    imgProc = np.array(img)
    
    predictions = model.predict(imgProc)
    for i in range(len(predictions)):
        predictions[i] = cv2.merge((predictions[i,:,:,0],predictions[i,:,:,1],predictions[i,:,:,2]))
    
    return predictions, imgProc, mask


def Plotter(img, predMask, groundTruth):
    plt.figure(figsize=(20,10))
    
    plt.subplot(1,3,1)
    plt.imshow(img)
    plt.title('Terrain Image')
    
    ## Adding Image sharpening step here
    ## it is a sharpening filter
    filter = np.array([[-1, -1, -1], [-1, 16, -1], [-1, -1, -1]]) 
    imgSharpen = cv2.filter2D(predMask,-1,filter)
    
    plt.subplot(1,3,2)
    plt.imshow(predMask)
    plt.title('Predicted Terrain Mask')
    
    plt.subplot(1,3,3)
    plt.imshow(groundTruth)
    plt.title('Actual Terrain Mask')

# %%
sixteenPrediction, actuals, masks = predict16(df, myTransformer)
Plotter(actuals[1], sixteenPrediction[1], masks[1])
# Out:
# 2023-04-02 13:11:57.714825: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
Plotter(actuals[0], sixteenPrediction[0], masks[0])

# %%
Plotter(actuals[14], sixteenPrediction[14], masks[14])
